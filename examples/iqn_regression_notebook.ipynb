# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("./iqn_regression_data.csv", header=None)
df2 = pd.read_csv("./iqn_regression_pred.csv", header=None)

# %%
df1.head()
# Out:
#           0          1
# 0  2.254763   2.337800
# 1  4.275640   4.365634
# 2  0.372451  -1.357543
# 3  1.488505   0.648205
# 4 -4.603474 -13.960071

# %%
plt.scatter(df1[0], df1[1])
plt.plot(df2[0], df2[1], label="tau=0.1")
plt.plot(df2[0], df2[2], label="tau=0.3")
plt.plot(df2[0], df2[3], label="tau=0.5")
plt.plot(df2[0], df2[4], label="tau=0.7")
plt.plot(df2[0], df2[5], label="tau=0.9")
plt.legend()
